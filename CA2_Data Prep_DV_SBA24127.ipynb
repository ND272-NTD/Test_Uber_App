# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import MultiLabelBinarizer
import re

# %%
movies = pd.read_csv("movies.csv", encoding='ISO-8859-1')
ratings = pd.read_csv("rating.csv", encoding='ISO-8859-1')
tags = pd.read_csv("tags.csv", encoding='ISO-8859-1')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
def extract_year(title):
    match = re.search(r'\((\d{4})\)', title)
    if match:
        return int(match.group(1))  # Extract and return the year as an integer
    return None  # Return None if no year is found

def remove_year_from_title(title):
    # Regular expression to remove the year in parentheses
    return re.sub(r'\s?\(\d{4}\)', '', title)

# Apply the functions to extract year and remove year from the title
movies['year'] = movies['title'].apply(extract_year)
movies['title'] = movies['title'].apply(remove_year_from_title)

# Preview the data to check the result
print(movies[['title', 'year']].head())
# Out:
#                          title  year
# 0                    Toy Story  1995
# 1                      Jumanji  1995
# 2             Grumpier Old Men  1995
# 3            Waiting to Exhale  1995
# 4  Father of the Bride Part II  1995

# %%
tag_counts = tags.groupby(['movieId', 'tag']).size().reset_index(name='tag_count')

tag_frequency = tags['tag'].value_counts().reset_index()
tag_frequency.columns = ['tag', 'total_count']

tag_counts_with_frequency = pd.merge(tag_counts, tag_frequency, on='tag', how='left')

# Calculate the "uniqueness" score (tags that are less frequent across movies should have a lower score)
tag_counts_with_frequency['uniqueness_score'] = tag_counts_with_frequency['total_count'].rank(method='min')

top_unique_tags_per_movie = tag_counts_with_frequency.groupby('movieId').apply(
    lambda x: x.nsmallest(5, 'uniqueness_score')).reset_index(drop=True)

top_unique_tags_aggregated = top_unique_tags_per_movie.groupby('movieId')['tag'].apply(lambda x: ', '.join(x)).reset_index()

top_unique_tags_with_titles = pd.merge(top_unique_tags_aggregated, movies[['movieId', 'title', 'year', 'genres']], on='movieId', how='left')

top_unique_tags_with_titles = top_unique_tags_with_titles[['movieId', 'title', 'year','genres', 'tag']]

print(top_unique_tags_with_titles[['title', 'tag']].head())

# Save the result to a CSV file
#top_unique_tags_with_titles.to_csv('top_5_unique_tags_per_movie.csv', index=False)
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                                  tag
# 0  TÃ©a Leoni does not star in this movie, toy, v...
# 1  see also:Zathura, Chris Van Allsburg, childhoo...
# 2  comedinha de velhinhos engraÃÂ§ada, comedinha...
# 3              characters, chick flick, revenge, CLV
# 4  steve martin, Diane Keaton, Steve Martin, Fant...
# C:\Users\niall\AppData\Local\Temp\ipykernel_42072\3480619443.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top_unique_tags_per_movie = tag_counts_with_frequency.groupby('movieId').apply(

# %%
movies=top_unique_tags_with_titles

# %%
movies.head(20)
# Out:
#     movieId                           title  year  \
# 0         1                       Toy Story  1995
# 1         2                         Jumanji  1995
# 2         3                Grumpier Old Men  1995
# 3         4               Waiting to Exhale  1995
# 4         5     Father of the Bride Part II  1995
# 5         6                            Heat  1995
# 6         7                         Sabrina  1995
# 7         9                    Sudden Death  1995
# 8        10                       GoldenEye  1995
# 9        11         American President, The  1995
# 10       12     Dracula: Dead and Loving It  1995
# 11       13                           Balto  1995
# 12       14                           Nixon  1995
# 13       15                Cutthroat Island  1995
# 14       16                          Casino  1995
# 15       17           Sense and Sensibility  1995
# 16       18                      Four Rooms  1995
# 17       19  Ace Ventura: When Nature Calls  1995
# 18       20                     Money Train  1995
# 19       21                      Get Shorty  1995
#
#                                          genres  \
# 0   Adventure|Animation|Children|Comedy|Fantasy
# 1                    Adventure|Children|Fantasy
# 2                                Comedy|Romance
# 3                          Comedy|Drama|Romance
# 4                                        Comedy
# 5                         Action|Crime|Thriller
# 6                                Comedy|Romance
# 7                                        Action
# 8                     Action|Adventure|Thriller
# 9                          Comedy|Drama|Romance
# 10                                Comedy|Horror
# 11                 Adventure|Animation|Children
# 12                                        Drama
# 13                     Action|Adventure|Romance
# 14                                  Crime|Drama
# 15                                Drama|Romance
# 16                                       Comedy
# 17                                       Comedy
# 18           Action|Comedy|Crime|Drama|Thriller
# 19                        Comedy|Crime|Thriller
#
#                                                   tag
# 0   TÃ©a Leoni does not star in this movie, toy, v...
# 1   see also:Zathura, Chris Van Allsburg, childhoo...
# 2   comedinha de velhinhos engraÃÂ§ada, comedinha...
# 3               characters, chick flick, revenge, CLV
# 4   steve martin, Diane Keaton, Steve Martin, Fant...
# 5   career criminal, individualism, tough guy, ONE...
# 6   remadeAs:Sabrina(1995), remakeOf:Sabrina(1954)...
# 7   Peter Hyams, Jean-Claude Van Damme, Can't reme...
# 8   007 movies are bad., tank chase scene, Puerto ...
# 9   23.03.06, Amazing kung fu, clever dialogue, de...
# 10                  Mel Brooks, vampire, gothic, BD-R
# 11    dogsled, sort of boring, Simon Wells, Ei muista
# 12  Historical opinion, character based on real pe...
# 13         Pirate, treasure, pirates, big budget, CLV
# 14    20060407, Pesci, Robert Deniro, Vegas, scorcese
# 15  period film, Period, available DVD, literature...
# 16  Tim Roth, Antonio Banderas, fast paced, 4, Tar...
# 17  spit, Steve Oedekerk, crazy, Stupid as Hell, o...
# 18                            Joseph Ruben, lame, CLV
# 19  Getting old but still excellent, travolta, aut...

# %%
avg_ratings = ratings.groupby('movieId')['rating'].mean().reset_index()

movies = pd.merge(movies, avg_ratings, on='movieId', how='left')

movies = movies.rename(columns={'rating': 'average_rating'})

movies.head(10)
# Out:
#    movieId                        title  year  \
# 0        1                    Toy Story  1995
# 1        2                      Jumanji  1995
# 2        3             Grumpier Old Men  1995
# 3        4            Waiting to Exhale  1995
# 4        5  Father of the Bride Part II  1995
# 5        6                         Heat  1995
# 6        7                      Sabrina  1995
# 7        9                 Sudden Death  1995
# 8       10                    GoldenEye  1995
# 9       11      American President, The  1995
#
#                                         genres  \
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                                       Action
# 8                    Action|Adventure|Thriller
# 9                         Comedy|Drama|Romance
#
#                                                  tag  average_rating
# 0  TÃ©a Leoni does not star in this movie, toy, v...        3.793347
# 1  see also:Zathura, Chris Van Allsburg, childhoo...        3.069892
# 2  comedinha de velhinhos engraÃÂ§ada, comedinha...        2.923077
# 3              characters, chick flick, revenge, CLV        2.576923
# 4  steve martin, Diane Keaton, Steve Martin, Fant...        2.848684
# 5  career criminal, individualism, tough guy, ONE...        3.818182
# 6  remadeAs:Sabrina(1995), remakeOf:Sabrina(1954)...        3.250000
# 7  Peter Hyams, Jean-Claude Van Damme, Can't reme...        2.634615
# 8  007 movies are bad., tank chase scene, Puerto ...        3.335968
# 9  23.03.06, Amazing kung fu, clever dialogue, de...        3.380734

# %%
movies.shape
# Out:
# (2495, 6)

# %%
movies.to_csv('movies_streamlit.csv', index=False)
